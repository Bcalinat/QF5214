# %%
import mysql.connector
import pandas as pd

# %%
data = pd.read_csv('../data/stock_price.csv')

# %%
data
# Out:
#        Unnamed: 0        Date        Open        High         Low       Close  \
# 0               0  2000-01-03   58.687500   59.312500   56.000000   58.281250
# 1               1  2000-01-04   56.781250   58.562500   56.125000   56.312500
# 2               2  2000-01-05   55.562500   58.187500   54.687500   56.906250
# 3               3  2000-01-06   56.093750   56.937500   54.187500   55.000000
# 4               4  2000-01-07   54.312500   56.125000   53.656250   55.718750
# ...           ...         ...         ...         ...         ...         ...
# 78522        6032  2023-12-22  410.589996  412.279999  408.760010  410.739990
# 78523        6033  2023-12-26  410.609985  411.730011  409.630005  409.929993
# 78524        6034  2023-12-27  408.000000  411.350006  408.000000  411.209991
# 78525        6035  2023-12-28  410.529999  410.899994  409.209991  409.769989
# 78526        6036  2023-12-29  408.720001  412.119995  407.959991  410.709991
#
# ...

# %%
def create_mysql_table():
    mydb = mysql.connector.connect(
        host="127.0.0.1",
        user="root",
        password="root",
        database="qf",
        port = "3307"
    )
    mycursor = mydb.cursor()
    mycursor.execute(
        '''CREATE TABLE stock_price (
            id INT AUTO_INCREMENT PRIMARY KEY, 
            date VARCHAR(255),
            symbol VARCHAR(10),
            open FLOAT,
            high FLOAT,
            low FLOAT,
            close FLOAT,
            adj_close FLOAT,
            volume BIGINT
            )
        '''
        )
    mydb.commit()
    mydb.close()

def insert_mysql_table(data):
    mydb = mysql.connector.connect(
        host="127.0.0.1",
        user="root",
        password="root",
        database="qf",
        port = "3307"
    )

    mycursor = mydb.cursor()

    for index, row in data.iterrows():
        sql = "INSERT INTO stock_price (date, symbol, open, high, low, close, adj_close, volume) VALUES (%s, %s, %s,%s, %s, %s,%s, %s)"
        val = (row['Date'], row['Symbol'],row['Open'],row['High'],row['Low'],row['Close'],row['Adj Close'],row['Volume'])
        mycursor.execute(sql, val)
        
    mydb.commit()
    mydb.close()

# %%
create_mysql_table()

# %%
insert_mysql_table(data)
